# %% [markdown]
# <a href="https://colab.research.google.com/github/amyrhuerta/evaluacion/blob/main/Evaluaci%C3%B3n_p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EVALUACION P3**
# Amairany Rodríguez | a01702927

# %%
#Instalamos librería para análisis de variables categóricas
#!pip install --upgrade setuptools
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached funpymodeling-0.1.7-py3-none-any.whl (6.4 kB)
# ...
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached seaborn-0.10.1-py3-none-any.whl (215 kB)
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=29e8581d2ed5207281b74fc9cae35d0aaa42b6d9ea9d7d47b4fcfb4a176209d8
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
# importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling.exploratory import freq_tbl

# %%
# declaramos nuestros dataframes
dfeua=pd.read_csv("dfeua SIN NULOS.csv")
dfmex=pd.read_csv("dfmex SIN NULOS.csv")
dfg=pd.read_csv("dfg SIN NULOS.csv", encoding= 'unicode_escape')

# %% [markdown]
# ## 'host_identity_verified' EUA

# %%
table1= freq_tbl(dfeua['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       6106    0.880334         0.880334
# 1                      f        830    0.119666         1.000000

# %%
table1_index= table1.set_index('host_identity_verified')
table1_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                            6106    0.880334         0.880334
# f                             830    0.119666         1.000000

# %%
table1_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## 'host_identity_verified' MEX

# %%
table1= freq_tbl(dfmex['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22300    0.920613         0.920613
# 1                      f       1923    0.079387         1.000000

# %%
table1_index= table1.set_index('host_identity_verified')
table1_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           22300    0.920613         0.920613
# f                            1923    0.079387         1.000000

# %%
table1_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## 'host_identity_verified' Girona

# %%
table1= freq_tbl(dfg['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       4950    0.873941         0.875796
# 1                      f        702    0.123941         1.000000

# %%
table1_index= table1.set_index('host_identity_verified')
table1_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                            4950    0.873941         0.875796
# f                             702    0.123941         1.000000

# %%
table1_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# Estas graficas nos ayudan a visulizar la cantidad de host que estan verificados en la plataforma de Airbnb. Principalmente, se observa que en México tenemos más opciones de reserva de Airbnb y por ende el porcentaje de host verificados es mayor que los de EUA y Girona.

# %% [markdown]
# ## property_type EUA

# %%
table2= freq_tbl(dfeua['property_type'])
table2
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       1848    0.266436         0.266436
# 1                         Entire condo        879    0.126730         0.393166
# 2                 Private room in home        853    0.122982         0.516148
# 3                          Entire home        839    0.120963         0.637111
# 4                   Entire guest suite        495    0.071367         0.708478
# 5          Private room in rental unit        471    0.067907         0.776384
# 6               Room in boutique hotel        352    0.050750         0.827134
# 7                        Room in hotel        265    0.038206         0.865340
# 8                Private room in condo        192    0.027682         0.893022
# 9            Entire serviced apartment        145    0.020905         0.913927
# 10                  Room in aparthotel         68    0.009804         0.923731
# ...

# %%
Filtro= table2[table2['frequency']>100]
Filtro
# Out:
#                  property_type  frequency  percentage  cumulative_perc
# 0           Entire rental unit       1848    0.266436         0.266436
# 1                 Entire condo        879    0.126730         0.393166
# 2         Private room in home        853    0.122982         0.516148
# 3                  Entire home        839    0.120963         0.637111
# 4           Entire guest suite        495    0.071367         0.708478
# 5  Private room in rental unit        471    0.067907         0.776384
# 6       Room in boutique hotel        352    0.050750         0.827134
# 7                Room in hotel        265    0.038206         0.865340
# 8        Private room in condo        192    0.027682         0.893022
# 9    Entire serviced apartment        145    0.020905         0.913927

# %%
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                1848    0.266436         0.266436
# Entire condo                       879    0.126730         0.393166
# Private room in home               853    0.122982         0.516148
# Entire home                        839    0.120963         0.637111
# Entire guest suite                 495    0.071367         0.708478
# Private room in rental unit        471    0.067907         0.776384
# Room in boutique hotel             352    0.050750         0.827134
# Room in hotel                      265    0.038206         0.865340
# Private room in condo              192    0.027682         0.893022
# Entire serviced apartment          145    0.020905         0.913927

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipos de propiedades')
plt.xlabel('Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## property_type MEX

# %%
table2= freq_tbl(dfmex['property_type'])
table2
# Out:
#                    property_type  frequency  percentage  cumulative_perc
# 0             Entire rental unit       8144    0.336209         0.336209
# 1                   Entire condo       3363    0.138835         0.475044
# 2    Private room in rental unit       2860    0.118070         0.593114
# 3           Private room in home       2009    0.082938         0.676052
# 4                    Entire loft       1584    0.065392         0.741444
# ..                           ...        ...         ...              ...
# 87                 Entire in-law          1    0.000041         0.999835
# 88          Private room in barn          1    0.000041         0.999876
# 89      Shared room in tiny home          1    0.000041         0.999917
# 90  Private room in earthen home          1    0.000041         0.999959
# 91           Shared room in tent          1    0.000041         1.000000
#
# [92 rows x 4 columns]

# %%
Filtro= table2[table2['frequency']>300]
Filtro
# Out:
#                  property_type  frequency  percentage  cumulative_perc
# 0           Entire rental unit       8144    0.336209         0.336209
# 1                 Entire condo       3363    0.138835         0.475044
# 2  Private room in rental unit       2860    0.118070         0.593114
# 3         Private room in home       2009    0.082938         0.676052
# 4                  Entire loft       1584    0.065392         0.741444
# 5    Entire serviced apartment       1067    0.044049         0.785493
# 6        Private room in condo        917    0.037857         0.823350
# 7                  Entire home        661    0.027288         0.850638
# 8                Room in hotel        381    0.015729         0.866367

# %%
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                8144    0.336209         0.336209
# Entire condo                      3363    0.138835         0.475044
# Private room in rental unit       2860    0.118070         0.593114
# Private room in home              2009    0.082938         0.676052
# Entire loft                       1584    0.065392         0.741444
# Entire serviced apartment         1067    0.044049         0.785493
# Private room in condo              917    0.037857         0.823350
# Entire home                        661    0.027288         0.850638
# Room in hotel                      381    0.015729         0.866367

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipos de propiedades')
plt.xlabel('Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## property_type Girona

# %%
table2= freq_tbl(dfg['property_type'])
table2
# Out:
#                property_type  frequency  percentage  cumulative_perc
# 0         Entire rental unit       2608    0.460452         0.460452
# 1                Entire home       1004    0.177260         0.637712
# 2               Entire villa        490    0.086511         0.724223
# 3               Entire condo        453    0.079979         0.804202
# 4             Entire cottage        192    0.033898         0.838100
# ..                       ...        ...         ...              ...
# 56              Private room          1    0.000177         0.999294
# 57       Private room in hut          1    0.000177         0.999470
# 58  Private room in bungalow          1    0.000177         0.999647
# 59                      Yurt          1    0.000177         0.999823
# 60          sin informaciÃ³n          1    0.000177         1.000000
#
# [61 rows x 4 columns]

# %%
Filtro= table2[table2['frequency']>100]
Filtro
# Out:
#         property_type  frequency  percentage  cumulative_perc
# 0  Entire rental unit       2608    0.460452         0.460452
# 1         Entire home       1004    0.177260         0.637712
# 2        Entire villa        490    0.086511         0.724223
# 3        Entire condo        453    0.079979         0.804202
# 4      Entire cottage        192    0.033898         0.838100
# 5    Entire townhouse        126    0.022246         0.860346

# %%
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit       2608    0.460452         0.460452
# Entire home              1004    0.177260         0.637712
# Entire villa              490    0.086511         0.724223
# Entire condo              453    0.079979         0.804202
# Entire cottage            192    0.033898         0.838100
# Entire townhouse          126    0.022246         0.860346

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipos de propiedades')
plt.xlabel('Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Observo en estas graficas que la mayoria de los tipos de propiedades registrados en las tres ciudades son entire rental unit. Dejandonos pensar que la mayoria de las opciones que se encuentran en la plataforma es este tipo de propiedades.

# %% [markdown]
# ## host_acceptance_rate EUA

# %%
table3= freq_tbl(dfeua['host_acceptance_rate'])
table3
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       2252    0.324683         0.324683
# 1       sin información        801    0.115484         0.440167
# 2                   99%        540    0.077855         0.518022
# 3                   97%        451    0.065023         0.583045
# 4                   98%        258    0.037197         0.620242
# ..                  ...        ...         ...              ...
# 82                  27%          2    0.000288         0.999279
# 83                  38%          2    0.000288         0.999567
# 84                  48%          1    0.000144         0.999712
# 85                  21%          1    0.000144         0.999856
# 86                  45%          1    0.000144         1.000000
#
# [87 rows x 4 columns]

# %%
Filtro= table3[table3['frequency']>200]
Filtro
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%       2252    0.324683         0.324683
# 1      sin información        801    0.115484         0.440167
# 2                  99%        540    0.077855         0.518022
# 3                  97%        451    0.065023         0.583045
# 4                  98%        258    0.037197         0.620242
# 5                  91%        216    0.031142         0.651384

# %%
Filtro_index= Filtro.set_index('host_acceptance_rate')
Filtro_index
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       2252    0.324683         0.324683
# sin información             801    0.115484         0.440167
# 99%                         540    0.077855         0.518022
# 97%                         451    0.065023         0.583045
# 98%                         258    0.037197         0.620242
# 91%                         216    0.031142         0.651384

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Porcentajes de aceptacion de el host')
plt.xlabel('% de aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## host_acceptance_rate MEX

# %%
table3= freq_tbl(dfmex['host_acceptance_rate'])
table3
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%      11616    0.479544         0.479544
# 1                   99%       2704    0.111629         0.591174
# 2       sin información       2043    0.084341         0.675515
# 3                   98%       1031    0.042563         0.718078
# 4                   97%        711    0.029352         0.747430
# ..                  ...        ...         ...              ...
# 86                  34%          2    0.000083         0.999835
# 87                  13%          1    0.000041         0.999876
# 88                   9%          1    0.000041         0.999917
# 89                  18%          1    0.000041         0.999959
# 90                  30%          1    0.000041         1.000000
#
# [91 rows x 4 columns]

# %%
Filtro= table3[table3['frequency']>600]
Filtro
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%      11616    0.479544         0.479544
# 1                  99%       2704    0.111629         0.591174
# 2      sin información       2043    0.084341         0.675515
# 3                  98%       1031    0.042563         0.718078
# 4                  97%        711    0.029352         0.747430
# 5                   0%        701    0.028939         0.776370

# %%
Filtro_index= Filtro.set_index('host_acceptance_rate')
Filtro_index
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479544         0.479544
# 99%                        2704    0.111629         0.591174
# sin información            2043    0.084341         0.675515
# 98%                        1031    0.042563         0.718078
# 97%                         711    0.029352         0.747430
# 0%                          701    0.028939         0.776370

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Porcentajes de aceptacion de el host')
plt.xlabel('% de aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## host_acceptance_rate Girona

# %%
table3= freq_tbl(dfg['host_acceptance_rate'])
table3
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       2262    0.399364         0.423516
# 1                   99%        764    0.134887         0.566561
# 2                   98%        345    0.060911         0.631155
# 3                   97%        224    0.039548         0.673095
# 4                   96%        184    0.032486         0.707545
# ..                  ...        ...         ...              ...
# 75                  10%          1    0.000177         0.999251
# 76                   7%          1    0.000177         0.999438
# 77                  42%          1    0.000177         0.999626
# 78                  45%          1    0.000177         0.999813
# 79                   9%          1    0.000177         1.000000
#
# [80 rows x 4 columns]

# %%
Filtro= table3[table3['frequency']>100]
Filtro
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%       2262    0.399364         0.423516
# 1                  99%        764    0.134887         0.566561
# 2                  98%        345    0.060911         0.631155
# 3                  97%        224    0.039548         0.673095
# 4                  96%        184    0.032486         0.707545
# 5                  91%        104    0.018362         0.727017
# 6                   0%        101    0.017832         0.745928

# %%
Filtro_index= Filtro.set_index('host_acceptance_rate')
Filtro_index
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       2262    0.399364         0.423516
# 99%                         764    0.134887         0.566561
# 98%                         345    0.060911         0.631155
# 97%                         224    0.039548         0.673095
# 96%                         184    0.032486         0.707545
# 91%                         104    0.018362         0.727017
# 0%                          101    0.017832         0.745928

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Porcentajes de aceptacion de el host')
plt.xlabel('% de aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Afortunadamente en las tres ciudades vemos que los host tienen un porcentaje de aceptacion del 100% o cercano al 100%. Por lo que cualquiera de estas tres ciudades rentar propiedades en esta aplicaciones es buena opción.

# %% [markdown]
# ## review_scores_communication Girona

# %%
dfg['review_scores_communication'] = dfg['review_scores_communication'].astype('object')
table4= freq_tbl(dfg['review_scores_communication'])
table4
# Out:
#      review_scores_communication  frequency  percentage  cumulative_perc
# 0                           5.00       1837    0.324329         0.324329
# 1                           0.00       1101    0.194386         0.518715
# 2                           4.00        219    0.038665         0.557380
# 3                           4.50        164    0.028955         0.586335
# 4                           4.67        154    0.027189         0.613524
# ..                           ...        ...         ...              ...
# 132                         3.78          1    0.000177         0.999294
# 133                         4.05          1    0.000177         0.999470
# 134                         3.45          1    0.000177         0.999647
# 135                         4.51          1    0.000177         0.999823
# 136                         4.39          1    0.000177         1.000000
#
# [137 rows x 4 columns]

# %%
Filtro= table4[table4['frequency']>100]
Filtro
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                         5.00       1837    0.324329         0.324329
# 1                         0.00       1101    0.194386         0.518715
# 2                         4.00        219    0.038665         0.557380
# 3                         4.50        164    0.028955         0.586335
# 4                         4.67        154    0.027189         0.613524
# 5                         4.75        101    0.017832         0.631356

# %%
Filtro_index= Filtro.set_index('review_scores_communication')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# review_scores_communication
# 5.00                              1837    0.324329         0.324329
# 0.00                              1101    0.194386         0.518715
# 4.00                               219    0.038665         0.557380
# 4.50                               164    0.028955         0.586335
# 4.67                               154    0.027189         0.613524
# 4.75                               101    0.017832         0.631356

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## review_scores_communication EUA

# %%
dfeua['review_scores_communication'] = dfeua['review_scores_communication'].astype('object')
table4= freq_tbl(dfeua['review_scores_communication'])
table4
# Out:
#      review_scores_communication  frequency  percentage  cumulative_perc
# 0                           5.00       2423    0.349337         0.349337
# 1                           0.00       1346    0.194060         0.543397
# 2                           4.98        206    0.029700         0.573097
# 3                           4.96        204    0.029412         0.602509
# 4                           4.97        189    0.027249         0.629758
# ..                           ...        ...         ...              ...
# 102                         4.22          1    0.000144         0.999423
# 103                         4.11          1    0.000144         0.999567
# 104                         4.59          1    0.000144         0.999712
# 105                         4.09          1    0.000144         0.999856
# 106                         3.88          1    0.000144         1.000000
#
# [107 rows x 4 columns]

# %%
Filtro= table4[table4['frequency']>150]
Filtro
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                         5.00       2423    0.349337         0.349337
# 1                         0.00       1346    0.194060         0.543397
# 2                         4.98        206    0.029700         0.573097
# 3                         4.96        204    0.029412         0.602509
# 4                         4.97        189    0.027249         0.629758
# 5                         4.95        178    0.025663         0.655421

# %%
Filtro_index= Filtro.set_index('review_scores_communication')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# review_scores_communication
# 5.00                              2423    0.349337         0.349337
# 0.00                              1346    0.194060         0.543397
# 4.98                               206    0.029700         0.573097
# 4.96                               204    0.029412         0.602509
# 4.97                               189    0.027249         0.629758
# 4.95                               178    0.025663         0.655421

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## review_scores_communication MEX

# %%
dfmex['review_scores_communication'] = dfmex['review_scores_communication'].astype('object')
table4= freq_tbl(dfmex['review_scores_communication'])
table4
# Out:
#      review_scores_communication  frequency  percentage  cumulative_perc
# 0                           5.00       7377    0.304545         0.304545
# 1                           0.00       3652    0.150766         0.455311
# 2                           4.94        596    0.024605         0.479916
# 3                           4.97        574    0.023696         0.503612
# 4                           4.93        559    0.023077         0.526690
# ..                           ...        ...         ...              ...
# 131                         2.71          1    0.000041         0.999835
# 132                         3.20          1    0.000041         0.999876
# 133                         4.12          1    0.000041         0.999917
# 134                         1.67          1    0.000041         0.999959
# 135                         1.50          1    0.000041         1.000000
#
# [136 rows x 4 columns]

# %%
Filtro= table4[table4['frequency']>550]
Filtro
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                         5.00       7377    0.304545         0.304545
# 1                         0.00       3652    0.150766         0.455311
# 2                         4.94        596    0.024605         0.479916
# 3                         4.97        574    0.023696         0.503612
# 4                         4.93        559    0.023077         0.526690
# 5                         4.95        554    0.022871         0.549560
# 6                         4.92        551    0.022747         0.572307

# %%
Filtro_index= Filtro.set_index('review_scores_communication')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# review_scores_communication
# 5.00                              7377    0.304545         0.304545
# 0.00                              3652    0.150766         0.455311
# 4.94                               596    0.024605         0.479916
# 4.97                               574    0.023696         0.503612
# 4.93                               559    0.023077         0.526690
# 4.95                               554    0.022871         0.549560
# 4.92                               551    0.022747         0.572307

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# Las tres ciudades analizadas tienen un regsitro de 5 estrellas de la comunicacion de los host en la palicación. Aunque es necesario decir, que la mayoria de las personas contestan 5 estrellas o no contesta este tipo de información.

# %% [markdown]
# ## availability_365 MEX

# %%
dfmex['availability_365'] = dfmex['availability_365'].astype('object')
table5= freq_tbl(dfmex['availability_365'])
table5
# Out:
#      availability_365  frequency  percentage  cumulative_perc
# 0                 365       2078    0.085786         0.085786
# 1                   0       1112    0.045907         0.131693
# 2                 364        894    0.036907         0.168600
# 3                 363        560    0.023119         0.191719
# 4                 362        557    0.022995         0.214713
# ..                ...        ...         ...              ...
# 361                 7          8    0.000330         0.998844
# 362               200          7    0.000289         0.999133
# 363                13          7    0.000289         0.999422
# 364               217          7    0.000289         0.999711
# 365               127          7    0.000289         1.000000
#
# [366 rows x 4 columns]

# %%
Filtro= table5[table5['frequency']>550]
Filtro
# Out:
#    availability_365  frequency  percentage  cumulative_perc
# 0               365       2078    0.085786         0.085786
# 1                 0       1112    0.045907         0.131693
# 2               364        894    0.036907         0.168600
# 3               363        560    0.023119         0.191719
# 4               362        557    0.022995         0.214713

# %%
Filtro_index= Filtro.set_index('availability_365')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# availability_365
# 365                    2078    0.085786         0.085786
# 0                      1112    0.045907         0.131693
# 364                     894    0.036907         0.168600
# 363                     560    0.023119         0.191719
# 362                     557    0.022995         0.214713

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## availability_365 EUA

# %%
dfeua['availability_365'] = dfeua['availability_365'].astype('object')
table5= freq_tbl(dfeua['availability_365'])
table5
# Out:
#      availability_365  frequency  percentage  cumulative_perc
# 0                   0        969    0.139706         0.139706
# 1                 365        276    0.039792         0.179498
# 2                 364        251    0.036188         0.215686
# 3                 179        146    0.021050         0.236736
# 4                  89        100    0.014418         0.251153
# ..                ...        ...         ...              ...
# 361               208          3    0.000433         0.998847
# 362               191          3    0.000433         0.999279
# 363               190          2    0.000288         0.999567
# 364               201          2    0.000288         0.999856
# 365               194          1    0.000144         1.000000
#
# [366 rows x 4 columns]

# %%
Filtro= table5[table5['frequency']>100]
Filtro
# Out:
#    availability_365  frequency  percentage  cumulative_perc
# 0                 0        969    0.139706         0.139706
# 1               365        276    0.039792         0.179498
# 2               364        251    0.036188         0.215686
# 3               179        146    0.021050         0.236736

# %%
Filtro_index= Filtro.set_index('availability_365')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# availability_365
# 0                       969    0.139706         0.139706
# 365                     276    0.039792         0.179498
# 364                     251    0.036188         0.215686
# 179                     146    0.021050         0.236736

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## availability_365 Girona

# %%
dfg['availability_365'] = dfg['availability_365'].astype('object')
table5= freq_tbl(dfg['availability_365'])
table5
# Out:
#      availability_365  frequency  percentage  cumulative_perc
# 0                   0        458    0.080862         0.080862
# 1                 365        112    0.019774         0.100636
# 2                 160         89    0.015713         0.116349
# 3                  90         47    0.008298         0.124647
# 4                  89         37    0.006532         0.131179
# ..                ...        ...         ...              ...
# 361                34          3    0.000530         0.998234
# 362                 6          3    0.000530         0.998764
# 363                38          3    0.000530         0.999294
# 364                12          3    0.000530         0.999823
# 365                19          1    0.000177         1.000000
#
# [366 rows x 4 columns]

# %%
Filtro= table5[table5['frequency']>35]
Filtro
# Out:
#    availability_365  frequency  percentage  cumulative_perc
# 0                 0        458    0.080862         0.080862
# 1               365        112    0.019774         0.100636
# 2               160         89    0.015713         0.116349
# 3                90         47    0.008298         0.124647
# 4                89         37    0.006532         0.131179
# 5               364         36    0.006356         0.137535

# %%
Filtro_index= Filtro.set_index('availability_365')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# availability_365
# 0                       458    0.080862         0.080862
# 365                     112    0.019774         0.100636
# 160                      89    0.015713         0.116349
# 90                       47    0.008298         0.124647
# 89                       37    0.006532         0.131179
# 364                      36    0.006356         0.137535

# %%
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# Esta grafica es soprendente pues en Girona no se cuenta con mucha informacion de si esta disponible las propiedades durante todo el año.En cambio en México la mayoria de las propiedades si cuentan con esta disponibilidad; de las tres ciudades este es el mayor con disponibilidad.
