# %% [markdown]
# <a href="https://colab.research.google.com/github/amyrhuerta/evaluacion/blob/main/EVALUACION_p2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EVALUACION P2**
#
# Amairany Rodríguez | a01702927

# %%
# importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# declaramos nuestros dataframes
dfeua=pd.read_csv("dfeua SIN NULOS.csv")
dfmex=pd.read_csv("dfmex SIN NULOS.csv")
dfg=pd.read_csv("dfg SIN NULOS.csv", encoding= 'unicode_escape')

# %% [markdown]
# ## host_acceptance_rate >50%

# %%
dfeua['host_acceptance_rate'] = dfeua['host_acceptance_rate'].str.replace('%', '')
dfeua['host_acceptance_rate'] = dfeua['host_acceptance_rate'].str.replace('sin información', '0')
dfeua['host_acceptance_rate'] = pd.to_numeric(dfeua['host_acceptance_rate'])

# %%
filtro1=dfeua[(dfeua['host_acceptance_rate']>50)]
filtro1.head()
# Out:
#    Unnamed: 0        id                          listing_url     scrape_id  \
# 0           0     958.0     https://www.airbnb.com/rooms/958  2.020000e+13
# 1           1    5858.0    https://www.airbnb.com/rooms/5858  2.020000e+13
# 2           2    8142.0    https://www.airbnb.com/rooms/8142  2.020000e+13
# 4           4    8739.0    https://www.airbnb.com/rooms/8739  2.020000e+13
# 5           5  142177.0  https://www.airbnb.com/rooms/142177  2.020000e+13
#
#   last_scraped       source  \
# 0   06/03/2023  city scrape
# 1   06/03/2023  city scrape
# 2   06/03/2023  city scrape
# 4   06/03/2023  city scrape
# 5   06/03/2023  city scrape
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                Mission Sunshine, with Private Bath
# 5                  Stylish, Spacious and Quiet Flat!
#
# ...

# %%
filtro1.to_csv("ACCEPTANCE DFEUA.csv")
from google.colab import files
files. download("ACCEPTANCE DFEUA.csv")

# %%
dfmex['host_acceptance_rate'] = dfmex['host_acceptance_rate'].str.replace('%', '')
dfmex['host_acceptance_rate'] = dfmex['host_acceptance_rate'].str.replace('sin información', '0')
dfmex['host_acceptance_rate'] = dfmex['host_acceptance_rate'].str.replace('Entire rental unit', '100') #se cree que quiere decir el 100%
dfmex['host_acceptance_rate'] = pd.to_numeric(dfmex['host_acceptance_rate'])

# %%
filtro1=dfmex[(dfmex['host_acceptance_rate']>50)]
filtro1.head()
# Out:
#    Unnamed: 0         id                           listing_url     scrape_id  \
# 2           2   696037.0   https://www.airbnb.com/rooms/696037  2.023030e+13
# 4           4    44616.0    https://www.airbnb.com/rooms/44616  2.023030e+13
# 5           5  2075738.0  https://www.airbnb.com/rooms/2075738  2.023030e+13
# 6           6    56074.0    https://www.airbnb.com/rooms/56074  2.023030e+13
# 7           7    61792.0    https://www.airbnb.com/rooms/61792  2.023030e+13
#
#   last_scraped       source  \
# 2     29/03/23  city scrape
# 4     30/03/23  city scrape
# 5     29/03/23  city scrape
# 6     29/03/23  city scrape
# 7     30/03/23  city scrape
#
#                                                 name  \
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 4                                  CONDESA HAUS  B&B
# 5                   Amazing apartment Mexico City!!!
# 6               Great space in historical San Rafael
# 7    Spacious Clean Quiet room (own bath) in Condesa
#
# ...

# %%
filtro1.to_csv("ACCEPTANCE DFEUA.csv")
from google.colab import files
files. download("ACCEPTANCE DFEUA.csv")

# %%
dfg['host_acceptance_rate'] = dfg['host_acceptance_rate'].str.replace('%', '')
dfg['host_acceptance_rate'] = dfg['host_acceptance_rate'].str.replace('sin información', '0')
dfg['host_acceptance_rate'] = pd.to_numeric(dfg['host_acceptance_rate'])

# %%
filtro1=dfg[(dfg['host_acceptance_rate']>50)]
filtro1.head()
# Out:
#          id                            listing_url     scrape_id last_scraped  \
# 0  31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13     01/04/23
# 1  30920857  https://www.airbnb.com/rooms/30920857  2.023030e+13     01/04/23
# 2  30922616  https://www.airbnb.com/rooms/30922616  2.023030e+13     01/04/23
# 3  30922622  https://www.airbnb.com/rooms/30922622  2.023030e+13     01/04/23
# 4  30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13     01/04/23
#
#         source                                               name  \
# 0  city scrape                   Eiffel Bridge Boutique Apartment
# 1  city scrape     Cozy Holiday Home in Calonge with Private Pool
# 2  city scrape      balmes - apartment with magnificent sea views
# 3  city scrape  casa paradis - semi-detached house with panoramic
# 4  city scrape  fanÃÂ©-mar 5 - apartment with spectacular vie...
#
#                                          description  \
# ...

# %%
filtro1.to_csv("ACCEPTANCE DFEUA.csv")
from google.colab import files
files. download("ACCEPTANCE DFEUA.csv")

# %% [markdown]
# ## Solo registros superhost

# %%
filtro2=dfeua[(dfeua['host_is_superhost']=="t")]
filtro2.head()
# Out:
#    Unnamed: 0        id                          listing_url     scrape_id  \
# 0           0     958.0     https://www.airbnb.com/rooms/958  2.020000e+13
# 4           4    8739.0    https://www.airbnb.com/rooms/8739  2.020000e+13
# 7           7   10537.0   https://www.airbnb.com/rooms/10537  2.020000e+13
# 8           8  491867.0  https://www.airbnb.com/rooms/491867  2.020000e+13
# 9           9  144242.0  https://www.airbnb.com/rooms/144242  2.020000e+13
#
#   last_scraped       source  \
# 0   06/03/2023  city scrape
# 4   06/03/2023  city scrape
# 7   06/03/2023  city scrape
# 8   06/03/2023  city scrape
# 9   06/03/2023  city scrape
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 4                Mission Sunshine, with Private Bath
# 7  Elegant & Cozy w/City views. Private room: Purple
# 8                  Central San Francisco Urban Dream
# 9                     Lake Street Single Family Home
#
# ...

# %%
filtro2.to_csv("SUPERHOST DFEUA.csv")
from google.colab import files
files. download("SUPERHOST DFEUA.csv")

# %%
filtro2=dfmex[(dfmex['host_is_superhost']=="t")]
filtro2.head()
# Out:
#    Unnamed: 0        id                          listing_url     scrape_id  \
# 2           2  696037.0  https://www.airbnb.com/rooms/696037  2.023030e+13
# 6           6   56074.0   https://www.airbnb.com/rooms/56074  2.023030e+13
# 7           7   61792.0   https://www.airbnb.com/rooms/61792  2.023030e+13
# 8           8  704779.0  https://www.airbnb.com/rooms/704779  2.023030e+13
# 9           9  728372.0  https://www.airbnb.com/rooms/728372  2.023030e+13
#
#   last_scraped       source  \
# 2     29/03/23  city scrape
# 6     29/03/23  city scrape
# 7     30/03/23  city scrape
# 8     29/03/23  city scrape
# 9     29/03/23  city scrape
#
#                                                 name  \
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 6               Great space in historical San Rafael
# 7    Spacious Clean Quiet room (own bath) in Condesa
# 8        SECURE BEST LOCATION City Center, Tours 104
# 9  Casa Indigo in the Center DF groups until 29 Pers
#
# ...

# %%
filtro2.to_csv("SUPERHOST DFMEX.csv")
from google.colab import files
files. download("SUPERHOST DFMEX.csv")

# %%
filtro2=dfg[(dfg['host_is_superhost']=="t")]
filtro2.head()
# Out:
#           id                            listing_url     scrape_id  \
# 0   31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13
# 12  31166377  https://www.airbnb.com/rooms/31166377  2.023030e+13
# 16  31167999  https://www.airbnb.com/rooms/31167999  2.023030e+13
# 17  31640563  https://www.airbnb.com/rooms/31640563  2.023030e+13
# 19  30925638  https://www.airbnb.com/rooms/30925638  2.023030e+13
#
#    last_scraped           source  \
# 0      01/04/23      city scrape
# 12     01/04/23      city scrape
# 16     01/04/23      city scrape
# 17     01/04/23      city scrape
# 19     01/04/23  previous scrape
#
#                                                  name  \
# 0                    Eiffel Bridge Boutique Apartment
# 12                                   Apartment Cortey
# 16  Lovely apartment with swimming pool in Begur town
# 17       Una Terraza con vistas al Mar y olor a Pinos
# 19  Coqueta casa con patio-jardÃÂ­n, barbacoa y c...
#
# ...

# %%
filtro2.to_csv("SUPERHOST DFG.csv")
from google.colab import files
files. download("SUPERHOST DFG.csv")

# %% [markdown]
# ## Regsitros que no verificaron su identidad

# %%
filtro3=dfeua[(dfeua['host_identity_verified']=="t")]
filtro3.head()
# Out:
#    Unnamed: 0      id                        listing_url     scrape_id  \
# 0           0   958.0   https://www.airbnb.com/rooms/958  2.020000e+13
# 1           1  5858.0  https://www.airbnb.com/rooms/5858  2.020000e+13
# 2           2  8142.0  https://www.airbnb.com/rooms/8142  2.020000e+13
# 3           3  8339.0  https://www.airbnb.com/rooms/8339  2.020000e+13
# 4           4  8739.0  https://www.airbnb.com/rooms/8739  2.020000e+13
#
#   last_scraped       source  \
# 0   06/03/2023  city scrape
# 1   06/03/2023  city scrape
# 2   06/03/2023  city scrape
# 3   06/03/2023  city scrape
# 4   06/03/2023  city scrape
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 3                    Historic Alamo Square Victorian
# 4                Mission Sunshine, with Private Bath
#
# ...

# %%
filtro3.to_csv("NO IDENTITY DFEUA.csv")
from google.colab import files
files. download("NO IDENTITY DFEUA.csv")

# %%
filtro3=dfmex[(dfmex['host_identity_verified']=="t")]
filtro3.head()
# Out:
#    Unnamed: 0         id                           listing_url     scrape_id  \
# 1           1  2072354.0  https://www.airbnb.com/rooms/2072354  2.023030e+13
# 2           2   696037.0   https://www.airbnb.com/rooms/696037  2.023030e+13
# 3           3    35797.0    https://www.airbnb.com/rooms/35797  2.023030e+13
# 4           4    44616.0    https://www.airbnb.com/rooms/44616  2.023030e+13
# 5           5  2075738.0  https://www.airbnb.com/rooms/2075738  2.023030e+13
#
#   last_scraped       source  \
# 1     30/03/23  city scrape
# 2     29/03/23  city scrape
# 3     29/03/23  city scrape
# 4     30/03/23  city scrape
# 5     29/03/23  city scrape
#
#                                                 name  \
# 1                 Coyoacan Historic Studio Apartment
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                        Villa Dante
# 4                                  CONDESA HAUS  B&B
# 5                   Amazing apartment Mexico City!!!
#
# ...

# %%
filtro3.to_csv("NO IDENTITY DFMEX.csv")
from google.colab import files
files. download("NO IDENTITY DFMEX.csv")

# %%
filtro3=dfg[(dfg['host_identity_verified']=="t")]
filtro3.head()
# Out:
#          id                            listing_url     scrape_id last_scraped  \
# 0  31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13     01/04/23
# 1  30920857  https://www.airbnb.com/rooms/30920857  2.023030e+13     01/04/23
# 2  30922616  https://www.airbnb.com/rooms/30922616  2.023030e+13     01/04/23
# 3  30922622  https://www.airbnb.com/rooms/30922622  2.023030e+13     01/04/23
# 4  30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13     01/04/23
#
#         source                                               name  \
# 0  city scrape                   Eiffel Bridge Boutique Apartment
# 1  city scrape     Cozy Holiday Home in Calonge with Private Pool
# 2  city scrape      balmes - apartment with magnificent sea views
# 3  city scrape  casa paradis - semi-detached house with panoramic
# 4  city scrape  fanÃÂ©-mar 5 - apartment with spectacular vie...
#
#                                          description  \
# ...

# %%
filtro3.to_csv("NO IDENTITY DFG.csv")
from google.colab import files
files. download("NO IDENTITY DFG.csv")

# %% [markdown]
# ## "Private Room" y "Hotel Room"

# %%
filtro4 = dfeua['room_type'].str.contains('Private room') | dfeua['room_type'].str.contains('Hotel room')
df_filtrado = dfeua[filtro4]
df_filtrado.head()
# Out:
#     Unnamed: 0        id                          listing_url     scrape_id  \
# 2            2    8142.0    https://www.airbnb.com/rooms/8142  2.020000e+13
# 4            4    8739.0    https://www.airbnb.com/rooms/8739  2.020000e+13
# 6            6  490931.0  https://www.airbnb.com/rooms/490931  2.020000e+13
# 7            7   10537.0   https://www.airbnb.com/rooms/10537  2.020000e+13
# 11          11  144978.0  https://www.airbnb.com/rooms/144978  2.020000e+13
#
#    last_scraped       source  \
# 2    06/03/2023  city scrape
# 4    06/03/2023  city scrape
# 6    06/03/2023  city scrape
# 7    06/03/2023  city scrape
# 11   06/03/2023  city scrape
#
#                                                  name  \
# 2   Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                 Mission Sunshine, with Private Bath
# 6                               Mission's "La Lengua"
# 7   Elegant & Cozy w/City views. Private room: Purple
# ...

# %%
#filtro3=dfeua[(dfeua['room_type']=="Private room'")]  | dfeua[(dfeua['room_type']=="Hotel room'")]

# %%
filtro4.to_csv("ROOMS DFEUA.csv")
from google.colab import files
files. download("ROOMS DFEUA.csv")

# %%
filtro4 = dfmex['room_type'].str.contains('Private room') | dfmex['room_type'].str.contains('Hotel room')
df_filtrado = dfmex[filtro4]
df_filtrado.head()
# Out:
#     Unnamed: 0         id                           listing_url     scrape_id  \
# 7            7    61792.0    https://www.airbnb.com/rooms/61792  2.023030e+13
# 14          14   737328.0   https://www.airbnb.com/rooms/737328  2.023030e+13
# 16          16   760912.0   https://www.airbnb.com/rooms/760912  2.023030e+13
# 17          17  2088218.0  https://www.airbnb.com/rooms/2088218  2.023030e+13
# 18          18  2093036.0  https://www.airbnb.com/rooms/2093036  2.023030e+13
#
#    last_scraped       source                                             name  \
# 7      30/03/23  city scrape  Spacious Clean Quiet room (own bath) in Condesa
# 14     29/03/23  city scrape                Business Suite BEIGE near Reforma
# 16     30/03/23  city scrape              Stylish bachelor pad in La Roma, DF
# 17     30/03/23  city scrape           Private rooms near old Coyoacan center
# 18     29/03/23  city scrape              Departamento 2 dormitorios x Antara
#
# ...

# %%
filtro4.to_csv("ROOMS DFMEX.csv")
from google.colab import files
files. download("ROOMS DFMEX.csv")

# %%
filtro4 = dfg['room_type'].str.contains('Private room') | dfg['room_type'].str.contains('Hotel room')
df_filtrado = dfg[filtro4]
df_filtrado.head()
# Out:
#            id                            listing_url     scrape_id  \
# 59   31685083  https://www.airbnb.com/rooms/31685083  2.023030e+13
# 109  31729062  https://www.airbnb.com/rooms/31729062  2.023030e+13
# 133  31814850  https://www.airbnb.com/rooms/31814850  2.023030e+13
# 143  31818389  https://www.airbnb.com/rooms/31818389  2.023030e+13
# 144  31818648  https://www.airbnb.com/rooms/31818648  2.023030e+13
#
#     last_scraped       source  \
# 59      31/03/23  city scrape
# 109     31/03/23  city scrape
# 133     31/03/23  city scrape
# 143     31/03/23  city scrape
# 144     31/03/23  city scrape
#
#                                                   name  \
# 59     Tranquila habitaciÃÂ³n a 5 minutos de Figueres
# 109  H en casa modernista.Parc Natural de Aiguamoll...
# 133                  Chambre calme a 3 kms de Figueres
# 143  H. n casa modernista. P. N. Aiguamolls d l'E. ...
# 144                        DOUBLE STANDARD PORTOCRISTO
#
# ...

# %%
filtro4.to_csv("ROOMS DFG.csv")
from google.colab import files
files. download("ROOMS DFG.csv")

# %% [markdown]
# ## Bathroom >1

# %%
filtro5=dfeua[(dfeua['bathrooms_text']=="1 bath")]
filtro5.head()
# Out:
#     Unnamed: 0        id                          listing_url     scrape_id  \
# 0            0     958.0     https://www.airbnb.com/rooms/958  2.020000e+13
# 1            1    5858.0    https://www.airbnb.com/rooms/5858  2.020000e+13
# 5            5  142177.0  https://www.airbnb.com/rooms/142177  2.020000e+13
# 6            6  490931.0  https://www.airbnb.com/rooms/490931  2.020000e+13
# 10          10   10578.0   https://www.airbnb.com/rooms/10578  2.020000e+13
#
#    last_scraped       source                                   name  \
# 0    06/03/2023  city scrape  Bright, Modern Garden Unit - 1BR/1BTH
# 1    06/03/2023  city scrape                     Creative Sanctuary
# 5    06/03/2023  city scrape      Stylish, Spacious and Quiet Flat!
# 6    06/03/2023  city scrape                  Mission's "La Lengua"
# 10   06/03/2023  city scrape    Classic Nob Hill Studio - Roof Deck
#
#                                           description  \
# ...

# %%
filtro5.to_csv("BATHROOM >1 DFEUA.csv")
from google.colab import files
files. download("BATHROOM >1 DFEUA.csv")

# %%
filtro5=dfmex[(dfmex['bathrooms_text']=="1 bath")]
filtro5.head()
# Out:
#     Unnamed: 0         id                           listing_url     scrape_id  \
# 1            1  2072354.0  https://www.airbnb.com/rooms/2072354  2.023030e+13
# 3            3    35797.0    https://www.airbnb.com/rooms/35797  2.023030e+13
# 6            6    56074.0    https://www.airbnb.com/rooms/56074  2.023030e+13
# 8            8   704779.0   https://www.airbnb.com/rooms/704779  2.023030e+13
# 10          10  2083241.0  https://www.airbnb.com/rooms/2083241  2.023030e+13
#
#    last_scraped       source  \
# 1      30/03/23  city scrape
# 3      29/03/23  city scrape
# 6      29/03/23  city scrape
# 8      29/03/23  city scrape
# 10     30/03/23  city scrape
#
#                                                  name  \
# 1                  Coyoacan Historic Studio Apartment
# 3                                         Villa Dante
# 6                Great space in historical San Rafael
# 8         SECURE BEST LOCATION City Center, Tours 104
# ...

# %%
filtro5.to_csv("BATHROOM >1 DFMEX.csv")
from google.colab import files
files. download("BATHROOM >1 DFMEX.csv")

# %%
filtro5=dfg[(dfg['bathrooms_text']=="1 bath")]
filtro5.head()
# Out:
#          id                            listing_url     scrape_id last_scraped  \
# 0  31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13     01/04/23
# 2  30922616  https://www.airbnb.com/rooms/30922616  2.023030e+13     01/04/23
# 4  30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13     01/04/23
# 5  30922643  https://www.airbnb.com/rooms/30922643  2.023030e+13     01/04/23
# 6  30922647  https://www.airbnb.com/rooms/30922647  2.023030e+13     01/04/23
#
#         source                                               name  \
# 0  city scrape                   Eiffel Bridge Boutique Apartment
# 2  city scrape      balmes - apartment with magnificent sea views
# 4  city scrape  fanÃÂ©-mar 5 - apartment with spectacular vie...
# 5  city scrape  mediterrÃÂ  ii 1-e  bright apartment situated...
# 6  city scrape  mimosas xi 1-2 beautiful apartment with terrac...
#
#                                          description  \
# ...

# %%
filtro5.to_csv("BATHROOM >1 DFG.csv")
from google.colab import files
files. download("BATHROOM >1 DFG.csv")

# %% [markdown]
# ## Precio >10k y "Entire home"

# %%
dfeua['price'] = dfeua['price'].str.replace('$', '')
dfeua['price'] = dfeua['price'].str.replace(',', '')
dfeua['price'] = pd.to_numeric(dfeua['price'])
#filtro6= dfeua[(dfeua['price'] > 10000 )] & dfeua[(dfeua['room_type']=="Entire home/apt'")]
filtro6 = dfeua[(dfeua['price'] > 10000) & (dfeua['room_type'].str.contains('Entire home/apt'))]
filtro6
# Out:
# <ipython-input-133-cf64ea8a89f9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dfeua['price'] = dfeua['price'].str.replace('$', '')
#       Unnamed: 0            id  \
# 5759        5759  6.430000e+17
# 6490        6490  7.860000e+17
#
#                                           listing_url     scrape_id  \
# 5759  https://www.airbnb.com/rooms/642886705473802703  2.020000e+13
# 6490  https://www.airbnb.com/rooms/785698957007308545  2.020000e+13
#
#      last_scraped       source                                   name  \
# 5759   06/03/2023  city scrape  Lovely 1-bedroom apartment with patio
# 6490   06/03/2023  city scrape                          Park Presidio
#
#                                             description  \
# 5759  Beautiful 1-bedroom perfect for the family who...
# ...

# %%
filtro6.to_csv("PRICE 10K & ENTIRE HOME DFEUA.csv")
from google.colab import files
files. download("PRICE 10K & ENTIRE HOME DFEUA.csv")

# %%
dfmex['price'] = dfmex['price'].str.replace('$', '')
dfmex['price'] = dfmex['price'].str.replace(',', '')
dfmex['price'] = pd.to_numeric(dfmex['price'])
#filtro6= dfmex[(dfmex['price'] > 10000 )] & dfmex[(dfmex['room_type']=="Entire home/apt'")]
filtro6 = dfmex[(dfmex['price'] > 10000) & (dfmex['room_type'].str.contains('Entire home/apt'))]
filtro6
# Out:
# <ipython-input-135-f46a5365f4eb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dfmex['price'] = dfmex['price'].str.replace('$', '')
#        Unnamed: 0            id  \
# 4               4  4.461600e+04
# 37             37  1.870300e+05
# 418           418  6.041044e+06
# 544           544  6.871835e+06
# 958           958  9.946549e+06
# ...           ...           ...
# 23249       23250  8.290750e+17
# 23467       23468  8.383780e+17
# 23690       23691  8.430860e+17
# 24102       24103  8.530480e+17
# 24191       24192  8.564410e+17
#
#                                            listing_url     scrape_id  \
# 4                   https://www.airbnb.com/rooms/44616  2.023030e+13
# 37                 https://www.airbnb.com/rooms/187030  2.023030e+13
# 418               https://www.airbnb.com/rooms/6041044  2.023030e+13
# ...

# %%
filtro6.to_csv("PRICE 10K & ENTIRE HOME DFMEX.csv")
from google.colab import files
files. download("PRICE 10K & ENTIRE HOME DFMEX.csv")

# %%
dfg['price'] = dfg['price'].str.replace('$', '')
dfg['price'] = dfg['price'].str.replace(',', '')
dfg['price'] = dfg['price'].str.replace('sin informaciÃ³n', '0')
dfg['price'] = pd.to_numeric(dfg['price'])
#filtro6= dfg[(dfg['price'] > 10000 )] & dfg[(dfmex['room_type']=="Entire home/apt'")]
filtro6 = dfg[(dfg['price'] > 10000) & (dfg['room_type'].str.contains('Entire home/apt'))]
filtro6
# Out:
# <ipython-input-137-142da5fd2000>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dfg['price'] = dfg['price'].str.replace('$', '')
#             id                            listing_url     scrape_id  \
# 148   31969327  https://www.airbnb.com/rooms/31969327  2.023030e+13
# 2584  41784831  https://www.airbnb.com/rooms/41784831  2.023030e+13
#
#      last_scraped       source                                         name  \
# 148      01/04/23  city scrape                                  La Portenya
# 2584     31/03/23  city scrape  Delux Villa in Vilacolum with Swimming Pool
#
#                                             description  \
# 148   Villa in Calonge, Catalonia, Spain with privat...
# 2584  Located in Vilacolum, this lavish 3-bedroom vi...
#
#             neighborhood_overview  \
# ...

# %%
filtro6.to_csv("PRICE 10K & ENTIRE HOME DFG.csv")
from google.colab import files
files. download("PRICE 10K & ENTIRE HOME DFG.csv")

# %% [markdown]
# ## review_scores_cleanliness >4.5

# %%
filtro7=dfeua[(dfeua['review_scores_cleanliness']>4.5)]
filtro7.head()
# Out:
#    Unnamed: 0        id                          listing_url     scrape_id  \
# 0           0     958.0     https://www.airbnb.com/rooms/958  2.020000e+13
# 1           1    5858.0    https://www.airbnb.com/rooms/5858  2.020000e+13
# 3           3    8339.0    https://www.airbnb.com/rooms/8339  2.020000e+13
# 4           4    8739.0    https://www.airbnb.com/rooms/8739  2.020000e+13
# 5           5  142177.0  https://www.airbnb.com/rooms/142177  2.020000e+13
#
#   last_scraped       source                                   name  \
# 0   06/03/2023  city scrape  Bright, Modern Garden Unit - 1BR/1BTH
# 1   06/03/2023  city scrape                     Creative Sanctuary
# 3   06/03/2023  city scrape        Historic Alamo Square Victorian
# 4   06/03/2023  city scrape    Mission Sunshine, with Private Bath
# 5   06/03/2023  city scrape      Stylish, Spacious and Quiet Flat!
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# ...

# %%
filtro7.to_csv("review_scores_cleanliness DFEUA.csv")
from google.colab import files
files. download("review_scores_cleanliness DFEUA.csv")

# %%
filtro7=dfmex[(dfmex['review_scores_cleanliness']>4.5)]
filtro7.head()
# Out:
#    Unnamed: 0         id                           listing_url     scrape_id  \
# 0           0  2056638.0  https://www.airbnb.com/rooms/2056638  2.023030e+13
# 1           1  2072354.0  https://www.airbnb.com/rooms/2072354  2.023030e+13
# 2           2   696037.0   https://www.airbnb.com/rooms/696037  2.023030e+13
# 4           4    44616.0    https://www.airbnb.com/rooms/44616  2.023030e+13
# 5           5  2075738.0  https://www.airbnb.com/rooms/2075738  2.023030e+13
#
#   last_scraped       source  \
# 0     30/03/23  city scrape
# 1     30/03/23  city scrape
# 2     29/03/23  city scrape
# 4     30/03/23  city scrape
# 5     29/03/23  city scrape
#
#                                                 name  \
# 0                 Amplio y luminoso loft en Coyoacán
# 1                 Coyoacan Historic Studio Apartment
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 4                                  CONDESA HAUS  B&B
# 5                   Amazing apartment Mexico City!!!
#
# ...

# %%
filtro7.to_csv("review_scores_cleanliness DFMEX.csv")
from google.colab import files
files. download("review_scores_cleanliness DFMEX.csv")

# %%
filtro7=dfg[(dfg['review_scores_cleanliness']>4.5)]
filtro7.head()
# Out:
#           id                            listing_url     scrape_id  \
# 0   31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13
# 10  31157780  https://www.airbnb.com/rooms/31157780  2.023030e+13
# 12  31166377  https://www.airbnb.com/rooms/31166377  2.023030e+13
# 15  31639963  https://www.airbnb.com/rooms/31639963  2.023030e+13
# 16  31167999  https://www.airbnb.com/rooms/31167999  2.023030e+13
#
#    last_scraped       source  \
# 0      01/04/23  city scrape
# 10     01/04/23  city scrape
# 12     01/04/23  city scrape
# 15     01/04/23  city scrape
# 16     01/04/23  city scrape
#
#                                                  name  \
# 0                    Eiffel Bridge Boutique Apartment
# 10  APARTAMENTOS AQUARIUM (2C). MUY CERCA DE LA PL...
# 12                                   Apartment Cortey
# 15               superbe villa en espagne costa brava
# 16  Lovely apartment with swimming pool in Begur town
#
# ...

# %%
filtro7.to_csv("review_scores_cleanliness DFG.csv")
from google.colab import files
files. download("review_scores_cleanliness DFG.csv")

# %% [markdown]
# ## review_scores_value >4.9

# %%
filtro9=dfeua[(dfeua['review_scores_value']>4.9)]
filtro9.head()
# Out:
#     Unnamed: 0        id                          listing_url     scrape_id  \
# 9            9  144242.0  https://www.airbnb.com/rooms/144242  2.020000e+13
# 24          24  149108.0  https://www.airbnb.com/rooms/149108  2.020000e+13
# 26          26   12522.0   https://www.airbnb.com/rooms/12522  2.020000e+13
# 46          46  530857.0  https://www.airbnb.com/rooms/530857  2.020000e+13
# 53          53  561602.0  https://www.airbnb.com/rooms/561602  2.020000e+13
#
#    last_scraped           source  \
# 9    06/03/2023      city scrape
# 24   06/03/2023      city scrape
# 26   06/03/2023  previous scrape
# 46   06/03/2023      city scrape
# 53   06/03/2023      city scrape
#
#                                                  name  \
# 9                      Lake Street Single Family Home
# 24      Luxury UCSF Cole Valley Condo w/Tesla Charger
# 26                           Perfectly located Castro
# 46             Sunny, quiet private room with parking
# ...

# %%
filtro9.to_csv("review_scores_value DFEUA.csv")
from google.colab import files
files. download("review_scores_value DFEUA.csv")

# %%
filtro9=dfmex[(dfmex['review_scores_value']>4.9)]
filtro9.head()
# Out:
#     Unnamed: 0         id                           listing_url     scrape_id  \
# 10          10  2083241.0  https://www.airbnb.com/rooms/2083241  2.023030e+13
# 11          11    67703.0    https://www.airbnb.com/rooms/67703  2.023030e+13
# 13          13    70644.0    https://www.airbnb.com/rooms/70644  2.023030e+13
# 24          24   783080.0   https://www.airbnb.com/rooms/783080  2.023030e+13
# 26          26  2118573.0  https://www.airbnb.com/rooms/2118573  2.023030e+13
#
#    last_scraped       source  \
# 10     30/03/23  city scrape
# 11     30/03/23  city scrape
# 13     29/03/23  city scrape
# 24     29/03/23  city scrape
# 26     30/03/23  city scrape
#
#                                                  name  \
# 10  Condesa Apartment in 1920s Landmarked Art Nouv...
# 11                  2 bedroom apt. deco bldg, Condesa
# 13   Beautiful light Studio Coyoacan- full equipped !
# 24                Nice quiet room in a lovely house!!
# ...

# %%
filtro9.to_csv("review_scores_value DFMEX.csv")
from google.colab import files
files. download("review_scores_value DFMEX.csv")

# %%
filtro9=dfg[(dfg['review_scores_value']>4.9)]
filtro9.head()
# Out:
#           id                            listing_url     scrape_id  \
# 4   30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13
# 15  31639963  https://www.airbnb.com/rooms/31639963  2.023030e+13
# 16  31167999  https://www.airbnb.com/rooms/31167999  2.023030e+13
# 26  30958272  https://www.airbnb.com/rooms/30958272  2.023030e+13
# 27  30959228  https://www.airbnb.com/rooms/30959228  2.023030e+13
#
#    last_scraped       source  \
# 4      01/04/23  city scrape
# 15     01/04/23  city scrape
# 16     01/04/23  city scrape
# 26     31/03/23  city scrape
# 27     31/03/23  city scrape
#
#                                                  name  \
# 4   fanÃÂ©-mar 5 - apartment with spectacular vie...
# 15               superbe villa en espagne costa brava
# 16  Lovely apartment with swimming pool in Begur town
# 26  Casa rural Can Miquel en el bosque y cerca del...
# 27  Pis Gran i Acollidor amb LLar de Foc, a Camprodon
#
# ...

# %%
filtro9.to_csv("review_scores_value DFG.csv")
from google.colab import files
files. download("review_scores_value DFG.csv")

# %% [markdown]
# ## availability_365 <100

# %%
filtro10=dfeua[(dfeua['availability_365']<100)]
filtro9.head()
# Out:
#           id                            listing_url     scrape_id  \
# 4   30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13
# 15  31639963  https://www.airbnb.com/rooms/31639963  2.023030e+13
# 16  31167999  https://www.airbnb.com/rooms/31167999  2.023030e+13
# 26  30958272  https://www.airbnb.com/rooms/30958272  2.023030e+13
# 27  30959228  https://www.airbnb.com/rooms/30959228  2.023030e+13
#
#    last_scraped       source  \
# 4      01/04/23  city scrape
# 15     01/04/23  city scrape
# 16     01/04/23  city scrape
# 26     31/03/23  city scrape
# 27     31/03/23  city scrape
#
#                                                  name  \
# 4   fanÃÂ©-mar 5 - apartment with spectacular vie...
# 15               superbe villa en espagne costa brava
# 16  Lovely apartment with swimming pool in Begur town
# 26  Casa rural Can Miquel en el bosque y cerca del...
# 27  Pis Gran i Acollidor amb LLar de Foc, a Camprodon
#
# ...

# %%
filtro10.to_csv("availability_365 DFEUA.csv")
from google.colab import files
files. download("availability_365 DFEUA.csv")

# %%
filtro10=dfmex[(dfmex['availability_365']<100)]
filtro10.head()
# Out:
#     Unnamed: 0         id                           listing_url     scrape_id  \
# 2            2   696037.0   https://www.airbnb.com/rooms/696037  2.023030e+13
# 21          21   131610.0   https://www.airbnb.com/rooms/131610  2.023030e+13
# 26          26  2118573.0  https://www.airbnb.com/rooms/2118573  2.023030e+13
# 37          37   187030.0   https://www.airbnb.com/rooms/187030  2.023030e+13
# 38          38   187745.0   https://www.airbnb.com/rooms/187745  2.023030e+13
#
#    last_scraped           source  \
# 2      29/03/23      city scrape
# 21     29/03/23      city scrape
# 26     30/03/23      city scrape
# 37     30/03/23  previous scrape
# 38     30/03/23  previous scrape
#
#                                                  name  \
# 2   3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 21                                     MARIA DEL ALMA
# 26  Walk to WTC from a Family Apartment in a Trend...
# 37      Spacious apt with the best rooftop in Condesa
# ...

# %%
filtro10.to_csv("availability_365 DFMEX.csv")
from google.colab import files
files. download("availability_365 DFMEX.csv")

# %%
filtro10=dfg[(dfg['availability_365']<100)]
filtro10.head()
# Out:
#           id                            listing_url     scrape_id  \
# 3   30922622  https://www.airbnb.com/rooms/30922622  2.023030e+13
# 4   30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13
# 8   31633472  https://www.airbnb.com/rooms/31633472  2.023030e+13
# 9   31157742  https://www.airbnb.com/rooms/31157742  2.023030e+13
# 12  31166377  https://www.airbnb.com/rooms/31166377  2.023030e+13
#
#    last_scraped       source  \
# 3      01/04/23  city scrape
# 4      01/04/23  city scrape
# 8      01/04/23  city scrape
# 9      01/04/23  city scrape
# 12     01/04/23  city scrape
#
#                                                  name  \
# 3   casa paradis - semi-detached house with panoramic
# 4   fanÃÂ©-mar 5 - apartment with spectacular vie...
# 8   DarÃÂ³ 3d 31 - close to the beach, pool, mosq...
# 9                          A la plage - Costabravaway
# 12                                   Apartment Cortey
#
# ...

# %%
filtro10.to_csv("availability_365 DFG.csv")
from google.colab import files
files. download("availability_365 DFG.csv")

# %% [markdown]
# ## host_response_time

# %%
filtro11=dfeua[(dfeua['host_response_time']== "within an hour")]
filtro11.head()
# Out:
#     Unnamed: 0        id                          listing_url     scrape_id  \
# 0            0     958.0     https://www.airbnb.com/rooms/958  2.020000e+13
# 2            2    8142.0    https://www.airbnb.com/rooms/8142  2.020000e+13
# 4            4    8739.0    https://www.airbnb.com/rooms/8739  2.020000e+13
# 5            5  142177.0  https://www.airbnb.com/rooms/142177  2.020000e+13
# 12          12  493889.0  https://www.airbnb.com/rooms/493889  2.020000e+13
#
#    last_scraped       source  \
# 0    06/03/2023  city scrape
# 2    06/03/2023  city scrape
# 4    06/03/2023  city scrape
# 5    06/03/2023  city scrape
# 12   06/03/2023  city scrape
#
#                                                  name  \
# 0               Bright, Modern Garden Unit - 1BR/1BTH
# 2   Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                 Mission Sunshine, with Private Bath
# 5                   Stylish, Spacious and Quiet Flat!
# ...

# %%
filtro11.to_csv("host_response_time DFEUA.csv")
from google.colab import files
files. download("host_response_time DFEUA.csv")

# %%
filtro11=dfmex[(dfmex['host_response_time']== "within an hour")]
filtro11.head()
# Out:
#    Unnamed: 0        id                          listing_url     scrape_id  \
# 2           2  696037.0  https://www.airbnb.com/rooms/696037  2.023030e+13
# 4           4   44616.0   https://www.airbnb.com/rooms/44616  2.023030e+13
# 6           6   56074.0   https://www.airbnb.com/rooms/56074  2.023030e+13
# 7           7   61792.0   https://www.airbnb.com/rooms/61792  2.023030e+13
# 8           8  704779.0  https://www.airbnb.com/rooms/704779  2.023030e+13
#
#   last_scraped       source  \
# 2     29/03/23  city scrape
# 4     30/03/23  city scrape
# 6     29/03/23  city scrape
# 7     30/03/23  city scrape
# 8     29/03/23  city scrape
#
#                                                 name  \
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 4                                  CONDESA HAUS  B&B
# 6               Great space in historical San Rafael
# 7    Spacious Clean Quiet room (own bath) in Condesa
# 8        SECURE BEST LOCATION City Center, Tours 104
#
# ...

# %%
filtro11.to_csv("host_response_time DFMEX.csv")
from google.colab import files
files. download("host_response_time DFMEX.csv")

# %%
filtro11=dfg[(dfg['host_response_time']== "within an hour")]
filtro11.head()
# Out:
#          id                            listing_url     scrape_id last_scraped  \
# 0  31143313  https://www.airbnb.com/rooms/31143313  2.023030e+13     01/04/23
# 1  30920857  https://www.airbnb.com/rooms/30920857  2.023030e+13     01/04/23
# 2  30922616  https://www.airbnb.com/rooms/30922616  2.023030e+13     01/04/23
# 3  30922622  https://www.airbnb.com/rooms/30922622  2.023030e+13     01/04/23
# 4  30922636  https://www.airbnb.com/rooms/30922636  2.023030e+13     01/04/23
#
#         source                                               name  \
# 0  city scrape                   Eiffel Bridge Boutique Apartment
# 1  city scrape     Cozy Holiday Home in Calonge with Private Pool
# 2  city scrape      balmes - apartment with magnificent sea views
# 3  city scrape  casa paradis - semi-detached house with panoramic
# 4  city scrape  fanÃÂ©-mar 5 - apartment with spectacular vie...
#
#                                          description  \
# ...

# %%
filtro11.to_csv("host_response_time DFG.csv")
from google.colab import files
files. download("host_response_time DFG.csv")
